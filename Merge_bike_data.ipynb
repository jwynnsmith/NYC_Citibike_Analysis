# %%
import pandas as pd
import csv
import datetime as dt

# %%
jan_df = pd.read_csv('201801-citibike-tripdata.csv')
jan_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929             505          6 Ave & W 33 St
# ...

# %%
#feb_df = pd.read_csv('201802-citibike-tripdata.csv')
#feb_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           771  2018-02-01 00:14:16.4120  2018-02-01 00:27:08.2290
# 1           264  2018-02-01 05:14:45.1790  2018-02-01 05:19:09.6860
# 2           819  2018-02-01 06:48:55.2290  2018-02-01 07:02:35.0290
# 3           646  2018-02-01 07:12:50.1740  2018-02-01 07:23:36.5280
# 4          1312  2018-02-01 07:46:48.8750  2018-02-01 08:08:41.5430
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id               end station name  \
# 0               -73.993929             379                W 31 St & 7 Ave
# ...

# %%
#mar_df = pd.read_csv('201803-citibike-tripdata.csv')
#mar_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           816  2018-03-01 02:29:13.7270  2018-03-01 02:42:50.1460
# 1           235  2018-03-01 05:12:37.0320  2018-03-01 05:16:32.1010
# 2          1250  2018-03-01 05:45:49.9000  2018-03-01 06:06:39.9080
# 3           741  2018-03-01 06:54:19.6150  2018-03-01 07:06:40.9790
# 4           727  2018-03-01 07:08:38.8610  2018-03-01 07:20:46.8500
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id               end station name  \
# 0               -73.993929             379                W 31 St & 7 Ave
# ...

# %%
#form = [jan_df, feb_df, mar_df]
#all_df = pd.concat(form)
#all_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929             505          6 Ave & W 33 St
# ...

# %%
# Keep first 10 characters in starttime column
#all_df["starttime"] = all_df["starttime"].str[:10]
#all_df["starttime"] = all_df["starttime"].str[:13]
#all_df.head()

jan_df["starttime"] = jan_df["starttime"].str[:10]
jan_df.head()
# Out:
#    tripduration   starttime                  stoptime  start station id  \
# 0           970  2018-01-01  2018-01-01 14:07:08.1860                72
# 1           723  2018-01-01  2018-01-01 15:45:33.3410                72
# 2           496  2018-01-01  2018-01-01 15:47:35.1720                72
# 3           306  2018-01-01  2018-01-01 15:45:20.1910                72
# 4           306  2018-01-01  2018-01-01 18:19:57.6420                72
#
#   start station name  start station latitude  start station longitude  \
# 0   W 52 St & 11 Ave               40.767272               -73.993929
# 1   W 52 St & 11 Ave               40.767272               -73.993929
# 2   W 52 St & 11 Ave               40.767272               -73.993929
# 3   W 52 St & 11 Ave               40.767272               -73.993929
# 4   W 52 St & 11 Ave               40.767272               -73.993929
#
#    end station id         end station name  end station latitude  \
# ...

# %%
date_hr_df = all_df["starttime"].str.split(" ", n = 1, expand = True)

# making seperate first name column from new data frame 
date_hr_df["Date"]= date_hr_df[0] 
  
# making seperate last name column from new data frame 
date_hr_df["Hour"]= date_hr_df[1] 
  
# Dropping old Name columns 
date_hr_df.drop(date_hr_df.columns[0]) 
date_hr_df.head()
# Out:
#             0   1        Date Hour
# 0  2018-01-01  13  2018-01-01   13
# 1  2018-01-01  15  2018-01-01   15
# 2  2018-01-01  15  2018-01-01   15
# 3  2018-01-01  15  2018-01-01   15
# 4  2018-01-01  18  2018-01-01   18

# %%
#YYYY-MM-DD to M/D/YYYY
#all_df['Date'] = pd.to_datetime(all_df['Date'], format='%Y-%m-%d').dt.strftime('%-m/%-d/%Y')
#all_df["starttime"] = all_df.dt.strftime("%m/%d/%Y")
#all_df.head()

jan_df['starttime'] = pd.to_datetime(jan_df['starttime'], format='%Y-%m-%d').dt.strftime('%-m/%-d/%Y')
#jan_df["starttime"] = jan_df.dt.strftime("%m/%d/%Y")
jan_df.head()
# Out:
#    tripduration starttime                  stoptime  start station id  \
# 0           970  1/1/2018  2018-01-01 14:07:08.1860                72
# 1           723  1/1/2018  2018-01-01 15:45:33.3410                72
# 2           496  1/1/2018  2018-01-01 15:47:35.1720                72
# 3           306  1/1/2018  2018-01-01 15:45:20.1910                72
# 4           306  1/1/2018  2018-01-01 18:19:57.6420                72
#
#   start station name  start station latitude  start station longitude  \
# 0   W 52 St & 11 Ave               40.767272               -73.993929
# 1   W 52 St & 11 Ave               40.767272               -73.993929
# 2   W 52 St & 11 Ave               40.767272               -73.993929
# 3   W 52 St & 11 Ave               40.767272               -73.993929
# 4   W 52 St & 11 Ave               40.767272               -73.993929
#
#    end station id         end station name  end station latitude  \
# ...

# %%
#all_df.rename(columns={"starttime": "Date"}, inplace=True)
#all_df["Date"] = all_df["Date"].str[:10]
#all_df.head()

jan_df.rename(columns={"starttime": "Date"}, inplace=True)
jan_df["Date"] = jan_df["Date"].str[:10]
jan_df.head()
# Out:
#    tripduration      Date                  stoptime  start station id  \
# 0           970  1/1/2018  2018-01-01 14:07:08.1860                72
# 1           723  1/1/2018  2018-01-01 15:45:33.3410                72
# 2           496  1/1/2018  2018-01-01 15:47:35.1720                72
# 3           306  1/1/2018  2018-01-01 15:45:20.1910                72
# 4           306  1/1/2018  2018-01-01 18:19:57.6420                72
#
#   start station name  start station latitude  start station longitude  \
# 0   W 52 St & 11 Ave               40.767272               -73.993929
# 1   W 52 St & 11 Ave               40.767272               -73.993929
# 2   W 52 St & 11 Ave               40.767272               -73.993929
# 3   W 52 St & 11 Ave               40.767272               -73.993929
# 4   W 52 St & 11 Ave               40.767272               -73.993929
#
#    end station id         end station name  end station latitude  \
# ...

# %%
date_hr_df2 = date_hr_df[["Date", "Hour"]]
date_hr_df2.head()
# Out:
#          Date Hour
# 0  2018-01-01   13
# 1  2018-01-01   15
# 2  2018-01-01   15
# 3  2018-01-01   15
# 4  2018-01-01   18

# %%
file_name = "Winter_2018_2.csv"
#all_df.to_csv(file_name, sep='\t', encoding='utf-8')
date_hr_df2.to_csv(file_name, sep='\t', encoding='utf-8')

# %%
file_name = "Winter_2018.csv"
all_df.to_csv(file_name, sep='\t', encoding='utf-8')

# %%
file_name = "Jan_2018.csv"
jan_df.to_csv(file_name, sep='\t', encoding='utf-8')
